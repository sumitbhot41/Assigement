# %%
Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of Matplotlib.

# %% [raw]
# Matplotlib is a popular Python library used for data visualization. It provides a wide variety of plotting functions and customization options to create high-quality graphs, charts, and plots. Matplotlib is extensively used in fields such as data analysis, scientific computing, machine learning, and more.

# %%
Five plots that can be plotted using the Pyplot module of Matplotlib are:

Line plot
Scatter plot
Bar plot
Histogram
Box plot

# %%
Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data plot a scatter plot.

# %% [raw]
# A scatter plot is a type of plot that displays values for two variables as points on a two-dimensional plane. It is used to observe relationships or patterns between the variables. Each point represents an observation in the dataset, where the x-coordinate corresponds to one variable and the y-coordinate corresponds to another variable

# %% [raw]
# import numpy as np
# import matplotlib.pyplot as plt
#
# np.random.seed(3)
# x = 3 + np.random.normal(0, 2, 50)
# y = 3 + np.random.normal(0, 2, len(x))
#
# plt.scatter(x, y)
# plt.title('Scatter Plot')
# plt.xlabel('X-axis')
# plt.ylabel('Y-axis')
# plt.show()

# %%
Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.

# %% [raw]
# The subplot() function in Matplotlib is used to create multiple plots within the same figure. It allows arranging plots in a grid-like fashion, specifying the number of rows and columns, and the position of each plot.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([0, 1, 2, 3, 4, 5])

# Line 1
y1 = np.array([0, 100, 200, 300, 400, 500])
plt.subplot(2, 2, 1)
plt.plot(x, y1)
plt.title('Line 1')

# Line 2
y2 = np.array([50, 20, 40, 20, 60, 70])
plt.subplot(2, 2, 2)
plt.plot(x, y2)
plt.title('Line 2')

# Line 3
y3 = np.array([10, 20, 30, 40, 50, 60])
plt.subplot(2, 2, 3)
plt.plot(x, y3)
plt.title('Line 3')

# Line 4
y4 = np.array([200, 350, 250, 550, 450, 150])
plt.subplot(2, 2, 4)
plt.plot(x, y4)
plt.title('Line 4')

plt.tight_layout()
plt.show()

# %%
What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.

# %% [raw]
# A bar plot is a type of plot that presents categorical data with rectangular bars. The length of each bar represents the value of the category it represents. Bar plots are used to compare different categories or to show the distribution of categorical data.

# %%
import numpy as np
import matplotlib.pyplot as plt

company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

plt.figure(figsize=(10, 5))

# Vertical bar plot
plt.subplot(1, 2, 1)
plt.bar(company, profit)
plt.title('Bar Plot')
plt.xlabel('Company')
plt.ylabel('Profit')

# Horizontal bar plot
plt.subplot(1, 2, 2)
plt.barh(company, profit)
plt.title('Horizontal Bar Plot')
plt.xlabel('Profit')
plt.ylabel('Company')

plt.tight_layout()
plt.show()

# %%
What is a box plot? Why is it used? Using the following data plot a box plot.

# %% [raw]
# A box plot, also known as a box-and-whisker plot, is a statistical representation of the distribution of a dataset. It displays the minimum, first quartile, median, third quartile, and maximum values of the dataset. Box plots are used to identify outliers, assess the symmetry and skewness of the data, and compare distributions between different groups.

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

plt.boxplot([box1, box2])
plt.title('Box Plot')
plt.xticks([1, 2], ['Box 1', 'Box 2'])
plt.ylabel('Values')
plt.show()
