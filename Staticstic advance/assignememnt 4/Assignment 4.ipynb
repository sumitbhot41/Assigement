# %%
# Q1: Difference between t-test and z-test
# T-test is used when sample size is small or population standard deviation is unknown.
# Z-test is used when sample size is large and population standard deviation is known.

# Example scenario:
# T-test: Comparing the mean exam scores of two different groups of students, each group having less than 30 students.
# Z-test: Comparing the mean exam scores of two different groups of students, each group having more than 30 students.

# Q2: Difference between one-tailed and two-tailed tests
# One-tailed test checks for the possibility of the relationship in one direction only.
# Two-tailed test checks for the possibility of the relationship in both directions.

# Q3: Type 1 and Type 2 errors
# Type 1 error occurs when the null hypothesis is rejected when it is actually true.
# Type 2 error occurs when the null hypothesis is accepted when it is actually false.

# Example scenario:
# Type 1 error: Rejecting the null hypothesis that a drug has no side effects when it actually does.
# Type 2 error: Accepting the null hypothesis that a drug has no side effects when it actually does have side effects.

# Q4: Explanation of Bayes's theorem
# Bayes's theorem calculates the probability of an event occurring given prior knowledge of related conditions.

# Example:
# P(A|B) = (P(B|A) * P(A)) / P(B)
# Where:
# P(A|B) = Probability of event A occurring given B has occurred
# P(B|A) = Probability of event B occurring given A has occurred
# P(A) = Probability of event A occurring
# P(B) = Probability of event B occurring

# Q5: Confidence interval
# A confidence interval is a range of values in which we are confident that the population parameter lies within.

# Example:
# If the 95% confidence interval for the population mean weight loss from a diet is (10, 15) pounds,
# it means we are 95% confident that the true mean weight loss is between 10 and 15 pounds.

# Q6: Bayes' Theorem application
# Sample problem: Given that 80% of emails are spam and a spam filter correctly identifies 95% of spam emails,
# calculate the probability that an email identified as spam is actually spam.

# Solution:
# P(Spam|Identified) = (P(Identified|Spam) * P(Spam)) / P(Identified)
# P(Spam|Identified) = (0.95 * 0.80) / P(Identified)

# Q7: Calculation of 95% confidence interval
# Mean = 50, Standard deviation = 5, Sample size = ?
# Margin of error = (Z * (Std Dev / sqrt(n)))
# 95% Confidence Interval = (Mean - Margin of error, Mean + Margin of error)

# Q8: Margin of error in a confidence interval
# Margin of error is the range above and below the sample statistic within which the population parameter is likely to lie.

# Example:
# With a larger sample size, the margin of error decreases, leading to a more precise estimate of the population parameter.

# Q9: Calculation of z-score
# Z-score = (X - μ) / σ
# Z-score = (75 - 70) / 5 = 1
# Interpretation: The data point is 1 standard deviation above the mean.

# Q10: Hypothesis test for the effectiveness of a weight loss drug
# Null hypothesis: The drug is not significantly effective (mean weight loss = 0)
# Alternative hypothesis: The drug is significantly effective (mean weight loss ≠ 0)
# Conduct a t-test using sample mean, standard deviation, sample size, and the assumed population mean.

# Q11: Calculation of 95% confidence interval for proportion
# Proportion = 0.65, Sample size = 500
# Margin of error = Z * sqrt((p * (1 - p)) / n)
# 95% Confidence Interval = (Proportion - Margin of error, Proportion + Margin of error)

# Q12: Hypothesis test for the effectiveness of teaching methods
# Null hypothesis: There is no significant difference in student performance between the two teaching methods.
# Alternative hypothesis: There is a significant difference in student performance between the two teaching methods.
# Conduct a t-test using sample means, standard deviations, and sample sizes of both samples.

# Q13: Calculation of 90% confidence interval for population mean
# Mean = 65, Standard deviation = 8, Sample size = 50
# Margin of error = Z * (Std Dev / sqrt(n))
# 90% Confidence Interval = (Mean - Margin of error, Mean + Margin of error)

# Q14: Hypothesis test for the effect of caffeine on reaction time
# Null hypothesis: Caffeine has no significant effect on reaction time (mean difference = 0)
# Alternative hypothesis: Caffeine has a significant effect on reaction time (mean difference ≠ 0)
# Conduct a t-test using sample mean, standard deviation, sample size, and the assumed population mean difference.
